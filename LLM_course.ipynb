# %% [markdown]
# # Toy Notebook for the LLM course on HuggingFace
#
# https://huggingface.co/learn/llm-course/chapter1/3

# %%
# getting access to HF models

from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis", model="meta-llama/Llama-3.2-1B")
classifier("I've been waiting for a HuggingFace course my whole life.")
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File ~/GenAI_Projects/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:761, in hf_raise_for_status(response, endpoint_name)
#     760 try:
# --> 761     response.raise_for_status()
#     762 except httpx.HTTPStatusError as e:
#
# File ~/GenAI_Projects/.venv/lib/python3.12/site-packages/httpx/_models.py:829, in Response.raise_for_status(self)
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '403 Forbidden' for url 'https://huggingface.co/meta-llama/Llama-3.2-1B/resolve/main/config.json'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/403
#
# The above exception was the direct cause of the following exception:
#
# GatedRepoError                            Traceback (most recent call last)
# File ~/GenAI_Projects/.venv/lib/python3.12/site-packages/transformers/utils/hub.py:422, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     420 if len(full_filenames) == 1:
#     421     # This is slightly better for only 1 file
# --> 422     hf_hub_download(
#     423         path_or_repo_id,
#     424         filenames[0],
#     425         subfolder=None if len(subfolder) == 0 else subfolder,
#     426         repo_type=repo_type,
#     427         revision=revision,
#     428         cache_dir=cache_dir,
#     429         user_agent=user_agent,
#     430         force_download=force_download,
#     431         proxies=proxies,
#     432         token=token,
#     433         local_files_only=local_files_only,
#     434         tqdm_class=tqdm_class,
#     435     )
#     436 else:
#
# File ~/GenAI_Projects/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File ~/GenAI_Projects/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:997, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, etag_timeout, token, local_files_only, headers, endpoint, tqdm_class, dry_run)
#     996 else:
# --> 997     return _hf_hub_download_to_cache_dir(
#     998         # Destination
#     999         cache_dir=cache_dir,
#    1000         # File info
#    1001         repo_id=repo_id,
#    1002         filename=filename,
#    1003         repo_type=repo_type,
#    1004         revision=revision,
#    1005         # HTTP info
#    1006         endpoint=endpoint,
#    1007         etag_timeout=etag_timeout,
#    1008         headers=hf_headers,
#    1009         token=token,
#    1010         # Additional options
#    1011         local_files_only=local_files_only,
#    1012         force_download=force_download,
#    1013         tqdm_class=tqdm_class,
#    1014         dry_run=dry_run,
#    1015     )
#
# File ~/GenAI_Projects/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1148, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, force_download, tqdm_class, dry_run)
#    1147     if head_call_error is not None:
# -> 1148         _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1150 # From now on, etag, commit_hash, url and size are not None.
#
# File ~/GenAI_Projects/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1782, in _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1777 elif isinstance(head_call_error, (RepositoryNotFoundError, GatedRepoError)) or (
#    1778     isinstance(head_call_error, HfHubHTTPError) and head_call_error.response.status_code == 401
#    1779 ):
#    1780     # Repo not found or gated => let's raise the actual error
#    1781     # Unauthorized => likely a token issue => let's raise the actual error
# -> 1782     raise head_call_error
#    1783 else:
#    1784     # Otherwise: most likely a connection issue or Hub downtime => let's warn the user
#
# File ~/GenAI_Projects/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1669, in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, relative_filename, storage_folder, retry_on_errors)
#    1668 try:
# -> 1669     metadata = get_hf_file_metadata(
#    1670         url=url,
#    1671         timeout=etag_timeout,
#    1672         headers=headers,
#    1673         token=token,
#    1674         endpoint=endpoint,
#    1675         retry_on_errors=retry_on_errors,
#    1676     )
#    1677 except RemoteEntryNotFoundError as http_error:
#
# File ~/GenAI_Projects/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File ~/GenAI_Projects/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1591, in get_hf_file_metadata(url, token, timeout, library_name, library_version, user_agent, headers, endpoint, retry_on_errors)
#    1590 # Retrieve metadata
# -> 1591 response = _httpx_follow_relative_redirects_with_backoff(
#    1592     method="HEAD", url=url, headers=hf_headers, timeout=timeout, retry_on_errors=retry_on_errors
#    1593 )
#    1594 hf_raise_for_status(response)
#
# File ~/GenAI_Projects/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:692, in _httpx_follow_relative_redirects_with_backoff(method, url, retry_on_errors, **httpx_kwargs)
#     685 response = http_backoff(
#     686     method=method,
#     687     url=url,
#    (...)    690     **no_retry_kwargs,
#     691 )
# --> 692 hf_raise_for_status(response)
#     694 # Check if response is a relative redirect
#
# File ~/GenAI_Projects/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:787, in hf_raise_for_status(response, endpoint_name)
#     784     message = (
#     785         f"{response.status_code} Client Error." + "\n\n" + f"Cannot access gated repo for url {response.url}."
#     786     )
# --> 787     raise _format(GatedRepoError, message, response, repo_type=repo_type, repo_id=repo_id) from e
#     789 elif error_message == "Access to this resource is disabled.":
#
# GatedRepoError: 403 Client Error. (Request ID: Root=1-69e797ed-6f2bae4819e51b6b4d150413;85975c3c-1ea7-4cb8-9e26-09ae5c2ec6f3)
#
# Cannot access gated repo for url https://huggingface.co/meta-llama/Llama-3.2-1B/resolve/main/config.json.
# Access to model meta-llama/Llama-3.2-1B is restricted and you are not in the authorized list. Visit https://huggingface.co/meta-llama/Llama-3.2-1B to ask for access.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 3
#       1 from transformers import pipeline
#       2
# ----> 3 classifier = pipeline("sentiment-analysis", model="meta-llama/Llama-3.2-1B")
#       4 classifier("I've been waiting for a HuggingFace course my whole life.")
#
# File ~/GenAI_Projects/.venv/lib/python3.12/site-packages/transformers/pipelines/__init__.py:704, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     701                 if not os.path.exists(model) or not os.path.exists(os.path.join(model, CONFIG_NAME)):
#     702                     model = adapter_config["base_model_name_or_path"]
# --> 704     config = AutoConfig.from_pretrained(
#     705         model, _from_pipeline=task, code_revision=code_revision, **hub_kwargs, **model_kwargs
#     706     )
#     707     hub_kwargs["_commit_hash"] = config._commit_hash
#     709 custom_tasks = {}
#
# File ~/GenAI_Projects/.venv/lib/python3.12/site-packages/transformers/models/auto/configuration_auto.py:1483, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1480 trust_remote_code = kwargs.pop("trust_remote_code", None)
#    1481 code_revision = kwargs.pop("code_revision", None)
# -> 1483 config_dict, unused_kwargs = PreTrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#    1484 has_remote_code = "auto_map" in config_dict and "AutoConfig" in config_dict["auto_map"]
#    1485 has_local_code = "model_type" in config_dict and config_dict["model_type"] in CONFIG_MAPPING
#
# File ~/GenAI_Projects/.venv/lib/python3.12/site-packages/transformers/configuration_utils.py:670, in PreTrainedConfig.get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     668 original_kwargs = copy.deepcopy(kwargs)
#     669 # Get config dict associated with the base config file
# --> 670 config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     671 if config_dict is None:
#     672     return {}, kwargs
#
# File ~/GenAI_Projects/.venv/lib/python3.12/site-packages/transformers/configuration_utils.py:725, in PreTrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     721 configuration_file = kwargs.pop("_configuration_file", CONFIG_NAME) if gguf_file is None else gguf_file
#     723 try:
#     724     # Load from local folder or from cache or download from model Hub and cache
# --> 725     resolved_config_file = cached_file(
#     726         pretrained_model_name_or_path,
#     727         configuration_file,
#     728         cache_dir=cache_dir,
#     729         force_download=force_download,
#     730         proxies=proxies,
#     731         local_files_only=local_files_only,
#     732         token=token,
#     733         user_agent=user_agent,
#     734         revision=revision,
#     735         subfolder=subfolder,
#     736         _commit_hash=commit_hash,
#     737     )
#     738     if resolved_config_file is None:
#     739         return None, kwargs
#
# File ~/GenAI_Projects/.venv/lib/python3.12/site-packages/transformers/utils/hub.py:278, in cached_file(path_or_repo_id, filename, **kwargs)
#     223 def cached_file(
#     224     path_or_repo_id: str | os.PathLike,
#     225     filename: str,
#     226     **kwargs,
#     227 ) -> str | None:
#     228     """
#     229     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     230
#    (...)    276     ```
#     277     """
# --> 278     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     279     file = file[0] if file is not None else file
#     280     return file
#
# File ~/GenAI_Projects/.venv/lib/python3.12/site-packages/transformers/utils/hub.py:488, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     486     if not _raise_exceptions_for_gated_repo:
#     487         return None
# --> 488     raise OSError(
#     489         "You are trying to access a gated repo.\nMake sure to have access to it at "
#     490         f"https://huggingface.co/{path_or_repo_id}.\n{str(e)}"
#     491     ) from e
#     492 elif isinstance(e, LocalEntryNotFoundError):
#     493     if not _raise_exceptions_for_connection_errors:
#
# OSError: You are trying to access a gated repo.
# Make sure to have access to it at https://huggingface.co/meta-llama/Llama-3.2-1B.
# 403 Client Error. (Request ID: Root=1-69e797ed-6f2bae4819e51b6b4d150413;85975c3c-1ea7-4cb8-9e26-09ae5c2ec6f3)
#
# Cannot access gated repo for url https://huggingface.co/meta-llama/Llama-3.2-1B/resolve/main/config.json.
# Access to model meta-llama/Llama-3.2-1B is restricted and you are not in the authorized list. Visit https://huggingface.co/meta-llama/Llama-3.2-1B to ask for access.

# %%
# several sentences

classifier(
    ["I've been waiting for a HuggingFace course my whole life.", "I hate this so much!"]
)

# %% [markdown]
# ### Zero shot classification

# %%
classifier = pipeline("zero-shot-classification")
classifier(
    "This is a course about the Transformers library",
    candidate_labels=["education", "politics", "business"],
)

# %% [markdown]
# ### Text Generation

# %%
generator = pipeline("text-generation")
generator("In this course, we will teach you how to")

# %% [markdown]
# ### Using any model from the Hub in the pipeline

# %%
generator = pipeline("text-generation", model="HuggingFaceTB/SmolLM2-360M")
generator(
    "In this course, we will teach you how to",
    max_length=30,
    num_return_sequences=2,
)

# %% [markdown]
# ### Mask filling

# %%
unmasker = pipeline("fill-mask")
unmasker("This course will teach you all about <mask> models.", top_k=2)

# %% [markdown]
# ### Named Entity Recognition

# %%
ner = pipeline("ner", grouped_entities=True)
ner("My name is Sylvain and I work at Hugging Face in Brooklyn.")

# %% [markdown]
# ### Question Answering

# %%
question_answerer = pipeline("question-answering")
question_answerer(
    question="Where do I work?",
    context="My name is Sylvain and I work at Hugging Face in Brooklyn",
)

# %% [markdown]
# ### Summarization

# %%
summarizer = pipeline("summarization")
summarizer(
    """
    America has changed dramatically during recent years. Not only has the number of 
    graduates in traditional engineering disciplines such as mechanical, civil, 
    electrical, chemical, and aeronautical engineering declined, but in most of 
    the premier American universities engineering curricula now concentrate on 
    and encourage largely the study of engineering science. As a result, there 
    are declining offerings in engineering subjects dealing with infrastructure, 
    the environment, and related issues, and greater concentration on high 
    technology subjects, largely supporting increasingly complex scientific 
    developments. While the latter is important, it should not be at the expense 
    of more traditional engineering.

    Rapidly developing economies such as China and India, as well as other 
    industrial countries in Europe and Asia, continue to encourage and advance 
    the teaching of engineering. Both China and India, respectively, graduate 
    six and eight times as many traditional engineers as does the United States. 
    Other industrial countries at minimum maintain their output, while America 
    suffers an increasingly serious decline in the number of engineering graduates 
    and a lack of well-educated engineers.
"""
)

# %% [markdown]
# ### Translation

# %%
translator = pipeline("translation", model="Helsinki-NLP/opus-mt-fr-en")
translator("Ce cours est produit par Hugging Face.")
